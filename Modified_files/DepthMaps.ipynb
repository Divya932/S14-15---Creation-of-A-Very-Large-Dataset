# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/ialhashim/DenseDepth.git
# Out:
# Cloning into 'DenseDepth'...
# remote: Enumerating objects: 235, done.
# remote: Total 235 (delta 0), reused 0 (delta 0), pack-reused 235
# Receiving objects: 100% (235/235), 11.80 MiB | 33.64 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# !unzip "/content/drive/My Drive/zipBatches/zipbatch1.zip" -d "/content/DenseDepth/"

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5
# Out:
# --2020-05-09 10:41:30--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.96.50
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.96.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./DenseDepth/nyu.h5’
#
# ./DenseDepth/nyu.h5 100%[===================>] 164.89M  28.4MB/s    in 6.5s
#
# 2020-05-09 10:41:37 (25.4 MB/s) - ‘./DenseDepth/nyu.h5’ saved [172897376/172897376]

# %%
import os
import shutil
from zipfile import ZipFile

#!unzip "/content/drive/My Drive/zipBatches/*.zip" -d "/content/DenseDepth/"

depth_path = '/content/DenseDepth/Depth_Masks'
mydir = os.path.isdir(depth_path)

if not mydir:
    os.makedirs(depth_path)
    print("Created folder: ", depth_path)

else:
    print(depth_path, "Folder already exists")

for count, filenm in enumerate(os.listdir('/content/DenseDepth/Deep Learning/MaskRCNN/bg_fg/')):
      
    # !cd DenseDepth; !python test.py --input '/content/DenseDepth/Deep Learning/MaskRCNN/bg_fg/*.jpg'
    zip_path = "/content/drive/My Drive/Depth_Zip/alldepths.zip"
    # !zip -r zip_path "/content/DenseDepth/Depth_Masks/"


    if( count < 50):
        unzip_path = os.path.join(drive_zip, zipfil)
        zip_obj = ZipFile(unzip_path, 'r')

        print("Unzipping: ",unzip_path)
        #zip_obj.extractall(unzip_path)
        #zip_obj.close()
        # !unzip zip_obj -d "/content/DenseDepth/"

        z = zipfil.split('h')
        c = z[1].split('.')
        shutil.rmtree('/content/DenseDepth/Depth_Masks/')
        shutil.rmtree('/content/DenseDepth/Deep Learning')
        print("Deleted folders Depth_Masks and Deep Learning")

    else:
        break

# %%
# !cd DenseDepth; python test.py --input 'Deep Learning/MaskRCNN/bg_fg/*.jpg'

print("test.py processed successfully")

#zip_path = "/content/drive/My Drive/Depth_Zip/batch_" + str(count+1) + ".zip"
# !cd "/content/drive/My Drive/Depth_Zip"
# !zip -r batch1.zip "/content/DenseDepth/Depth_Masks/"

# %%
zip_path = os.path.join("/content/drive/My Drive/Depth_Zip/batch_",str(0),".zip"
# !zip -r zip_path "/content/DenseDepth/Depth_Masks/"
# Out:
#   adding: content/DenseDepth/Depth_Masks/ (stored 0%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100708.jpg (deflated 4%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100339.jpg (deflated 5%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100450.jpg (deflated 7%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_10067.jpg (deflated 5%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100507.jpg (deflated 6%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100398.jpg (deflated 7%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100150.jpg (deflated 5%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100359.jpg (deflated 6%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100577.jpg (deflated 7%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100106.jpg (deflated 6%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_10023.jpg (deflated 5%)
#   adding: content/DenseDepth/Depth_Masks/depth_P_100723.jpg (deflated 5%)
# ...

# %%
import shutil
shutil.rmtree('/content/DenseDepth/Depth_Masks/')
#shutil.rmtree('/content/DenseDepth/Deep Learning')

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )
